# %%
# Step 1: Import required libraries
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# Step 2: Upload your dataset (Run this cell to upload)
from google.colab import files
uploaded = files.upload()  # Upload the .txt dataset

# Step 3: Read the uploaded file
for filename in uploaded.keys():
    with open(filename, 'r', encoding='utf-8') as file:
        text = file.read()

# Check the first 500 characters to ensure the text loaded correctly
print(text[:500])

# Step 4: Tokenize the text
tokenizer = Tokenizer()
tokenizer.fit_on_texts([text])
total_words = len(tokenizer.word_index) + 1

# Step 5: Create input-output sequences using n-grams
input_sequences = []
for line in text.split('\n'):
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i+1]
        input_sequences.append(n_gram_sequence)

# Step 6: Pad the sequences to have equal length
max_sequence_len = max([len(seq) for seq in input_sequences])
input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_sequence_len, padding='pre'))

# Step 7: Split data into input (X) and output (y)
X = input_sequences[:, :-1]
y = input_sequences[:, -1]

# Step 8: One-hot encode the output labels
y = tf.keras.utils.to_categorical(y, num_classes=total_words)

# Step 9: Build the LSTM model
model = Sequential()
model.add(Embedding(total_words, 100))
model.add(LSTM(150))
model.add(Dense(total_words, activation='softmax'))
model.summary()

# Step 10: Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Step 11: Train the model (Adjust epochs based on your dataset size)
model.fit(X, y, epochs=10, verbose=1)

# Step 12: Predict the next words based on seed text
# Step 12: Predict the next words based on user input

# Take the seed text from the user
seed_text = input("Enter the starting text: ")  # User will enter the input text here
next_words = int(input("Enter the number of words to predict: "))  # Number of words to predict

# Generate predictions
for _ in range(next_words):
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
    predicted = np.argmax(model.predict(token_list), axis=-1)
    output_word = ""

    for word, index in tokenizer.word_index.items():
        if index == predicted:
            output_word = word
            break

    seed_text += " " + output_word

print(f"Generated Text: {seed_text}")
# Out:
#      <input type="file" id="files-11adb517-dc75-430c-a5b3-fb093a643a15" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-11adb517-dc75-430c-a5b3-fb093a643a15">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
